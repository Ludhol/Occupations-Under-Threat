# %% [markdown]
# # Model Calibration
# In this Notebook data is used to calibrate the parameters of the Model
#
# This may either be done via the complete method or by using the deterministic approximatite solution
#
# The results from RM were useful in knowing where to look in the parameter space and to know how the model should behave.
# The calibrated values for RM were used as a starting point and optimal parameters were searched for in a space looking like that one.

# %%
# Import packages
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
import networkx as nx
import pandas as pd
import numpy as np
import scipy as sp
import datetime as dt
import community
from shapely.geometry import Polygon
import importlib

import DDOM # Data Driven Occupational Mobility
import model_cal

import random
import math

import simpy

import cmocean as cmo


# %matplotlib inline

# %%
# Read the data from data_processing.ipynb
sa_calibration_data = pd.read_csv('../Data_Labour/calibration_data.csv')
employment_SSYK = pd.read_csv('../Data_Labour/occupational_employment.csv', sep = ',')
SSYK_shock = pd.read_csv('../Data_Labour/occupation_shock.csv', sep = ',')

G = nx.read_graphml('../Data_Labour/Occ_mob_sweden.graphml')

# %%
# Model calibration using Deterministic Solution

# Re import DDOM Package
importlib.reload(DDOM)

# Calibration data structure
parameters = {}

# Visual inspection of Beveridge curve gives following period
parameters['years'] = 1
parameters['T'] = 15


# REALLY GOOD a: 0.03 delta_u: 0.012 delta_nu: 0.0001 gamma_u: 0.25 timestep: 6
# a: 0.03 delta_u: 0.014 delta_nu: 0.001 gamma_u: 0.225 timestep: 6

parameters['a'] = [0.02]
parameters['delta_u'] = [0.012]
parameters['delta_nu'] = [0.001]
parameters['gamma_u'] = [0.20]
parameters['timestep'] = [6]

parameters['gamma_ny'] = parameters['gamma_u']



# Calibration data
start = 18
end = 59
empirical_data = sa_calibration_data.iloc[start:end]

# Shock parameters (not there yet)
parameters['t_0'] = 1
parameters['k'] = 1
parameters['L'] = 1
parameters['avg_hours_0'] = 1
parameters['shock_start'] = 1

# output variable
calibration_output = True


e_vac_rate = empirical_data['sa_vac_rate']
e_unemployed = empirical_data['u_trend']
e_seq = [(u, e_vac_rate.iloc[i]) for i, u in enumerate(e_unemployed)]

plt.plot(e_unemployed, e_vac_rate, ls = '-', marker = 'o', linewidth = 1, markersize = 2)
plt.show()

# Loop should give result = {dict with parameters:dict with outputs}
results = []
no_sim = len(parameters['timestep'])*len(parameters['delta_u'])*len(parameters['delta_nu'])*len(parameters['gamma_u'])*len(parameters['a'])
print('Number of simulations -ish:', no_sim)
simulation_index = 0
for timestep in parameters['timestep']:
    for delta_nu in parameters['delta_nu']:
        for delta_u in parameters['delta_u']:
            for a in parameters['a']:
                for gamma_u in parameters['gamma_u']:
                    if delta_u <= delta_nu:
                        continue
                    print('Simulation index:', simulation_index)
                    print('a:', a, 'delta_u:', delta_u, 'delta_nu:', delta_nu, 'gamma_u:', gamma_u, 'timestep:', timestep)
                    employment = employment_SSYK[['SSYK', '2014']]
                    employment = {str(employment['SSYK'].iloc[i]):employment['2014'].iloc[i] for i in range(len(employment))}
                    node_names = list(G.nodes())

                    # setup network
                    employed = {str(name):e for name,e in employment.items() if str(name) in node_names}
                    unemployed = {name:0 for name in node_names}
                    vacancies = {name:0 for name in node_names}
                    applications = {name:[] for name in node_names}
                    target_demand = {str(name):e for name,e in employment.items() if str(name) in node_names}
                    of_data = SSYK_shock.groupby(by = ['ssyk3'], axis = 0).mean()
                    of_data = of_data.to_dict()['Computerisation Probability']
                    attributes = {'employed':employed, 'unemployed':unemployed, 'vacancies':vacancies, 'applications':applications,
                    'target_demand':target_demand, 'comp_prob':of_data}

                    # Save parameters
                    out_parameters = {'a':a, 'delta_u':delta_u, 'delta_nu':delta_nu, 'gamma_u':gamma_u, 'timestep':timestep}

                    # Run simulation
                    output = DDOM.deterministic_simulation(G, parameters['years'], timestep, delta_u, gamma_u, delta_nu, gamma_u, empirical_data,
                    parameters['t_0'], parameters['k'], parameters['L'], parameters['avg_hours_0'], a, parameters['T'], parameters['shock_start'],
                    attributes, calibration_output)
                    
                    # Save cost if < best_cost

                    print('cost:', output['cost'], 'A_e:', output['A_e'], 'A_m:', output['A_m'])

                    for key, val in out_parameters.items():
                        output[key] = val

                    results.append(output)
                    simulation_index += 1
# Out:
# Number of simulations -ish: 1
# Simulation index: 0
# a: 0.02 delta_u: 0.012 delta_nu: 0.001 gamma_u: 0.2 timestep: 6
# Simulation started at:  2020-05-08 00:23:40.652275
# A_m is not valid
# Simulation took:  0:02:02.232430
# cost: N/A A_e: 2.172216802022734 A_m: N/A

# %%
# Model calibration using Deterministic Solution

# Re import DDOM Package
importlib.reload(DDOM)

# Calibration data structure
parameters = {}

# Visual inspection of Beveridge curve gives following period
parameters['years'] = 1
parameters['T'] = 15


# REALLY GOOD a: 0.03 delta_u: 0.012 delta_nu: 0.0001 gamma_u: 0.25 timestep: 6
# a: 0.03 delta_u: 0.014 delta_nu: 0.001 gamma_u: 0.225 timestep: 6

parameters['a'] = [0.02]
parameters['delta_u'] = [0.012]
parameters['delta_nu'] = [0.001]
parameters['gamma_u'] = [0.20]
parameters['timestep'] = [6]

parameters['gamma_ny'] = parameters['gamma_u']



# Calibration data
start = 18
end = 59
empirical_data = sa_calibration_data.iloc[start:end]

# Shock parameters (not there yet)
parameters['t_0'] = 1
parameters['k'] = 1
parameters['L'] = 1
parameters['avg_hours_0'] = 1
parameters['shock_start'] = 1

# output variable
calibration_output = True


e_vac_rate = empirical_data['sa_vac_rate']
e_unemployed = empirical_data['u_trend']
e_seq = [(u, e_vac_rate.iloc[i]) for i, u in enumerate(e_unemployed)]

plt.plot(e_unemployed, e_vac_rate, ls = '-', marker = 'o', linewidth = 1, markersize = 2)
plt.show()

# Loop should give result = {dict with parameters:dict with outputs}
results = []
no_sim = len(parameters['timestep'])*len(parameters['delta_u'])*len(parameters['delta_nu'])*len(parameters['gamma_u'])*len(parameters['a'])
print('Number of simulations -ish:', no_sim)
simulation_index = 0
for timestep in parameters['timestep']:
    for delta_nu in parameters['delta_nu']:
        for delta_u in parameters['delta_u']:
            for a in parameters['a']:
                for gamma_u in parameters['gamma_u']:
                    if delta_u <= delta_nu:
                        continue
                    print('Simulation index:', simulation_index)
                    print('a:', a, 'delta_u:', delta_u, 'delta_nu:', delta_nu, 'gamma_u:', gamma_u, 'timestep:', timestep)
                    employment = employment_SSYK[['SSYK', '2014']]
                    employment = {str(employment['SSYK'].iloc[i]):employment['2014'].iloc[i] for i in range(len(employment))}
                    node_names = list(G.nodes())

                    # setup network
                    employed = {str(name):e for name,e in employment.items() if str(name) in node_names}
                    unemployed = {name:0 for name in node_names}
                    vacancies = {name:0 for name in node_names}
                    applications = {name:[] for name in node_names}
                    target_demand = {str(name):e for name,e in employment.items() if str(name) in node_names}
                    of_data = SSYK_shock.groupby(by = ['ssyk3'], axis = 0).mean()
                    of_data = of_data.to_dict()['Computerisation Probability']
                    attributes = {'employed':employed, 'unemployed':unemployed, 'vacancies':vacancies, 'applications':applications,
                    'target_demand':target_demand, 'comp_prob':of_data}

                    # Save parameters
                    out_parameters = {'a':a, 'delta_u':delta_u, 'delta_nu':delta_nu, 'gamma_u':gamma_u, 'timestep':timestep}

                    # Run simulation
                    output = DDOM.deterministic_simulation(G, parameters['years'], timestep, delta_u, gamma_u, delta_nu, gamma_u, empirical_data,
                    parameters['t_0'], parameters['k'], parameters['L'], parameters['avg_hours_0'], a, parameters['T'], parameters['shock_start'],
                    attributes, calibration_output)
                    
                    # Save cost if < best_cost

                    print('cost:', output['cost'], 'A_e:', output['A_e'], 'A_m:', output['A_m'])

                    for key, val in out_parameters.items():
                        output[key] = val

                    results.append(output)
                    simulation_index += 1
# Out:
# Number of simulations -ish: 4
# Simulation index: 0
# a: 0.02 delta_u: 0.012 delta_nu: 0.001 gamma_u: 0.2 timestep: 6
# Simulation started at:  2020-05-07 12:10:49.914604
# A_m is not valid
# Simulation took:  0:02:57.744242
# cost: N/A A_e: 2.172216802022734 A_m: N/A
# Simulation index: 1
# a: 0.02 delta_u: 0.012 delta_nu: 0.001 gamma_u: 0.2 timestep: 6
# Simulation started at:  2020-05-07 12:13:47.713320
# A_m is not valid
# Simulation took:  0:02:13.595762
# cost: N/A A_e: 2.172216802022734 A_m: N/A
# Simulation index: 2
# a: 0.02 delta_u: 0.012 delta_nu: 0.001 gamma_u: 0.2 timestep: 6
# Simulation started at:  2020-05-07 12:16:01.344363
# A_m is not valid
# Simulation took:  0:02:58.325986
# cost: N/A A_e: 2.172216802022734 A_m: N/A
# Simulation index: 3
# a: 0.02 delta_u: 0.012 delta_nu: 0.001 gamma_u: 0.2 timestep: 6
# Simulation started at:  2020-05-07 12:18:59.745732
# A_m is not valid
# Simulation took:  0:02:29.802315
# cost: N/A A_e: 2.172216802022734 A_m: N/A

# %%
# Model calibration using Deterministic Solution

# Re import DDOM Package
importlib.reload(DDOM)

# Calibration data structure
parameters = {}

# Visual inspection of Beveridge curve gives following period
parameters['years'] = 1
parameters['T'] = 15


# REALLY GOOD a: 0.03 delta_u: 0.012 delta_nu: 0.0001 gamma_u: 0.25 timestep: 6
# a: 0.03 delta_u: 0.014 delta_nu: 0.001 gamma_u: 0.225 timestep: 6
# a: 0.02 delta_u: 0.012 delta_nu: 0.0005 gamma_u: 0.2 timestep: 6

parameters['a'] = [0.02]
parameters['delta_u'] = [0.012, 0.013, 0.014]
parameters['delta_nu'] = [0.0005, 0.001, 0.002, 0.003]
parameters['gamma_u'] = [0.20, 0.25, 0.3]
parameters['timestep'] = [6]

p_list = [{'a': 0.03, 'delta_u': 0.012, 'delta_nu': 0.0001, 'gamma_u': 0.25, 'timestep': 6},
        {'a': 0.03, 'delta_u': 0.014, 'delta_nu': 0.001, 'gamma_u': 0.225, 'timestep': 6},
        {'a': 0.02, 'delta_u': 0.012, 'delta_nu': 0.0005, 'gamma_u': 0.2, 'timestep': 6}]

# Calibration data
start = 18
end = 59
empirical_data = sa_calibration_data.iloc[start:end]

# Shock parameters (not there yet)
parameters['t_0'] = 1
parameters['k'] = 1
parameters['L'] = 1
parameters['avg_hours_0'] = 1
parameters['shock_start'] = 1

# output variable
calibration_output = True

e_vac_rate = empirical_data['sa_vac_rate']
e_unemployed = empirical_data['u_trend']
e_seq = [(u, e_vac_rate.iloc[i]) for i, u in enumerate(e_unemployed)]

plt.plot(e_unemployed, e_vac_rate, ls = '-', marker = 'o', linewidth = 1, markersize = 2)
plt.show()

# Loop should give result = {dict with parameters:dict with outputs}
results = []
no_sim = len(parameters['timestep'])*len(parameters['delta_u'])*len(parameters['delta_nu'])*len(parameters['gamma_u'])*len(parameters['a'])
print('Number of simulations -ish:', no_sim)
simulation_index = 0

print('Simulation index:', simulation_index)

for params in p_list:
    print('a:', a, 'delta_u:', delta_u, 'delta_nu:', delta_nu, 'gamma_u:', gamma_u, 'timestep:', timestep)
    employment = employment_SSYK[['SSYK', '2014']]
    employment = {str(employment['SSYK'].iloc[i]):employment['2014'].iloc[i] for i in range(len(employment))}
    node_names = list(G.nodes())

    # setup network
    employed = {str(name):e for name,e in employment.items() if str(name) in node_names}
    unemployed = {name:0 for name in node_names}
    vacancies = {name:0 for name in node_names}
    applications = {name:[] for name in node_names}
    target_demand = {str(name):e for name,e in employment.items() if str(name) in node_names}
    of_data = SSYK_shock.groupby(by = ['ssyk3'], axis = 0).mean()
    of_data = of_data.to_dict()['Computerisation Probability']
    attributes = {'employed':employed, 'unemployed':unemployed, 'vacancies':vacancies, 'applications':applications,
    'target_demand':target_demand, 'comp_prob':of_data}

    # Save parameters
    out_parameters = {'a':a, 'delta_u':delta_u, 'delta_nu':delta_nu, 'gamma_u':gamma_u, 'timestep':timestep}

    # Run simulation
    output = DDOM.deterministic_simulation(G, parameters['years'], params['timestep'], params['delta_u'], params['gamma_u'], params['delta_nu'], params['gamma_u'], empirical_data, parameters['t_0'], parameters['k'], parameters['L'], parameters['avg_hours_0'], params['a'], parameters['T'], parameters['shock_start'], attributes, calibration_output)
    
    # Save cost if < best_cost

    print('cost:', output['cost'], 'A_e:', output['A_e'], 'A_m:', output['A_m'])

    for key, val in out_parameters.items():
        output[key] = val

    results.append(output)
    simulation_index += 1
# Out:
# Number of simulations -ish: 36
# Simulation index: 0
# a: 0.02 delta_u: 0.012 delta_nu: 0.001 gamma_u: 0.2 timestep: 6
# Simulation started at:  2020-05-07 16:28:59.813911
# A_m is not valid
# Simulation took:  0:01:57.585860
# cost: N/A A_e: 2.172216802022734 A_m: N/A
# a: 0.02 delta_u: 0.012 delta_nu: 0.001 gamma_u: 0.2 timestep: 6
# Simulation started at:  2020-05-07 16:30:57.473486
# A_m is not valid
# Simulation took:  0:01:50.707081
# cost: N/A A_e: 2.172216802022734 A_m: N/A
# a: 0.02 delta_u: 0.012 delta_nu: 0.001 gamma_u: 0.2 timestep: 6
# Simulation started at:  2020-05-07 16:32:48.204614
# A_m is not valid
# Simulation took:  0:01:52.084724
# cost: N/A A_e: 2.172216802022734 A_m: N/A
